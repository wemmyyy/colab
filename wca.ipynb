# %% [markdown]
# <a href="https://colab.research.google.com/github/wemmyyy/colab/blob/main/wca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
rafaela = input("rafaela chata: ")
print("concordo")
